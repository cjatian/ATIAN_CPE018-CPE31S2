# %% [markdown]
# <a href="https://colab.research.google.com/github/cjatian/ATIAN_CPE018-CPE31S2/blob/main/ATIAN_PRELIM_EXAM_CPE31S2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **31. Write a Python script using OpenCV that:**
#
# 1. Reads an image named "nature.jpg"
# 2. Converts it to grayscale
# 3. Resizes it to 300x300 pixels
# 4. Saves the result as "processed.jpg"

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install opencv-python
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
import cv2
import numpy as np

cv2.imread('/content/drive/CPE 018/nature.jpg')

# %% [markdown]
# **32. You have an image named circles.png containing various circles  circles Links to an external site. of different sizes. Write a Python script using OpenCV that:**
#
#   1. Load and preprocess the image
#   2. Detect circles using Hough Circle Transform
#   3. Draw detected circles in red color
#   4. Save the result as circles_detected.png
